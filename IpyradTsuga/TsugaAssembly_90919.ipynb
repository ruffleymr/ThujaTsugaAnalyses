# %%
## INSTALLATION
## -------------------------------------------------------------------------------------------

## conda install ipyrad -c ipyrad
## conda install toytree -c eaton-lab

## import ipyrad into python for api
import ipyrad as ip
import ipyparallel as ipp
import ipyrad.analysis as ipa

# %%
## PARRALELIZATION
## -------------------------------------------------------------------------------------------

## run the below line in terminal, or with '!', not in jupyter notebooks
## this will start and ipcluster 
#!ipcluster start -n 48 --cluster-id="ipyrad" --daemonize

## this will stop ipcluster
#!ipcluster stop --cluster-id="ipyrad" 

## check to make sure the client is working
## should print the number of cores ready to go
ipyclient = ipp.Client(cluster_id="ipyrad")

# %%
## check client
print(len(ipyclient))
#ipyclient.ids
# Out:
# 48

# %% [markdown]
# # Lib 1

# %%
## Now we will demultiplex the second library set, we will do this in the same way as the first set. 
data_lib1 = ip.Assembly("tsuga_lib1")
data_lib1.set_params("raw_fastq_path", "./*lib1.fastq.gz")
data_lib1.set_params("barcodes_path", "./barcodes_lib1.txt")
data_lib1.set_params("datatype", "ddrad")
data_lib1.set_params("output_formats", "*")
data_lib1.set_params("restriction_overhang", ("TGCAG", "CCGG"))

data_lib1.get_params()
# Out:
# New Assembly: tsuga_lib1
# 0   assembly_name               tsuga_lib1
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              ./*lib1.fastq.gz
# 3   barcodes_path               ./barcodes_lib1.txt
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             0
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %% [markdown]
# # Lib 2

# %%
## Now we will demultiplex the second library set, we will do this in the same way as the first set. 
data_lib2 = ip.Assembly("tsuga_lib2")
data_lib2.set_params("raw_fastq_path", "./*lib2.fastq.gz")
data_lib2.set_params("barcodes_path", "./barcodes_lib2.txt")
data_lib2.set_params("datatype", "ddrad")
data_lib2.set_params("output_formats", "*")
data_lib2.set_params("restriction_overhang", ("TGCAG", "CCGG"))

data_lib2.get_params()
# Out:
# New Assembly: tsuga_lib2
# 0   assembly_name               tsuga_lib2
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              ./*lib2.fastq.gz
# 3   barcodes_path               ./barcodes_lib2.txt
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             0
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %% [markdown]
# # Lib 3

# %%
## Now we will demultiplex the third library set. 
data_lib3 = ip.Assembly("tsuga_lib3")
data_lib3.set_params("raw_fastq_path", "./*lib3.fastq.gz")
data_lib3.set_params("barcodes_path", "./barcodes_lib3.txt")
data_lib3.set_params("datatype", "ddrad")
data_lib3.set_params("output_formats", "*")
data_lib3.set_params("restriction_overhang", ("TGCAG", "CCGG"))

data_lib3.get_params()
# Out:
# New Assembly: tsuga_lib3
# 0   assembly_name               tsuga_lib3
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              ./*lib3.fastq.gz
# 3   barcodes_path               ./barcodes_lib3.txt
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             0
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %% [markdown]
# # Lib 4

# %%
## Now we will demultiplex the third library set. 
data_lib4 = ip.Assembly("tsuga_lib4")
data_lib4.set_params("raw_fastq_path", "./*lib4.fastq.gz")
data_lib4.set_params("barcodes_path", "./barcodes_lib4.txt")
data_lib4.set_params("datatype", "ddrad")
data_lib4.set_params("output_formats", "*")
data_lib4.set_params("restriction_overhang", ("TGCAG", "CCGG"))

data_lib4.get_params()
# Out:
# New Assembly: tsuga_lib4
# 0   assembly_name               tsuga_lib4
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              ./*lib4.fastq.gz
# 3   barcodes_path               ./barcodes_lib4.txt
# 4   sorted_fastq_path
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             0
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %% [markdown]
# # Demultiplex all four libraries

# %%
## run the first library through step 1 
data_lib1.run("1", ipyclient=ipyclient)
# Out:
#   Assembly: tsuga_lib1
#   [####################] 100%  sorting reads         | 0:01:22 | s1 |
#   [####################] 100%  writing/compressing   | 0:17:12 | s1 |

# %%
## use the '!' and cat command to view the stats file summarizing step 1
data_lib1.stats
# Out:
# raw_file                               total_reads    cut_found  bar_matched
# tsuga_R1_lib1.fastq                       92383189     92377196     81437196
# tsuga_R2_lib1.fastq                       92383189     92382358          415
#
# sample_name                            total_reads
# S006                                      10111530
# S011                                       3281231
# S016                                       4889141
# S024                                       2030919
# S069                                          8220
# S081                                      11101092
# S128                                        652186
# S136                                      27629244
# S142                                       7227747
# S322                                       8845425
# S324                                       2840110
# S332                                       2820766
#
# sample_name                               true_bar       obs_bar     N_records
# S006                                         CTTGA         CTTGA      10111530
# S011                                         CTAGC         CTAGC       3281231
# S016                                         TTCTC         TTCTC       4889141
# S024                                         GTATT         GTATT       2030919
# S069                                        ATCACG        ATCACG          8220
# S081                                        TTAGGC        TTAGGC      11101092
# S128                                       ATGAAAC       ATGAAAC        652186
# S136                                       GAATTCA       GAATTCA      27629244
# S142                                        ACAGTG        ACAGTG       7227747
# S322                                         AGCAT         AGCAT       8845425
# S324                                        CGATGT        CGATGT       2840110
# S332                                       TATTTTT       TATTTTT       2820766
# no_match                                         _            _    103328767

# %%
## run the second library through step 1 
data_lib2.run("1", ipyclient=ipyclient)
# Out:
# Parallel connection | tesla.ibest.uidaho.edu: 30 cores
# [####################] 100% 0:34:46 | sorting reads        | s1 |
# [####################] 100% 0:01:08 | writing/compressing  | s1 |

# %%
## use the '!' and cat command to view the stats file summarizing step 1
data_lib2.run
# Out:
# raw_file                               total_reads    cut_found  bar_matched
# tsuga_R1_lib2.fastq                      116773615    116765715    107153806
# tsuga_R2_lib2.fastq                      116773615    116773139          372
#
# sample_name                            total_reads
# S014                                       5161631
# S072                                          6183
# S085                                      12231998
# S096                                       7325899
# S131                                       4107097
# S133                                       1153533
# S140                                      30741507
# S176                                       9736582
# S323                                      10526134
# S330                                      11896726
# S336                                       8068046
# S492                                       6198842
#
# sample_name                               true_bar       obs_bar     N_records
# S014                                         CTTGA         CTTGA       5161631
# S072                                        ATCACG        ATCACG          6183
# S085                                        TTAGGC        TTAGGC      12231998
# S096                                        ACAGTG        ACAGTG       7325899
# S131                                       TATTTTT       TATTTTT       4107097
# S133                                       ATGAAAC       ATGAAAC       1153533
# S140                                       GAATTCA       GAATTCA      30741507
# S176                                         CTAGC         CTAGC       9736582
# S323                                         GTATT         GTATT      10526134
# S330                                         TTCTC         TTCTC      11896726
# S336                                         AGCAT         AGCAT       8068046
# S492                                        CGATGT        CGATGT       6198842
# no_match                                         _             _     126393052

# %%
## run the third library through step 1 
data_lib3.run("1", ipyclient=ipyclient)
# Out:
# Parallel connection | tesla.ibest.uidaho.edu: 30 cores
# [####################] 100% 0:23:42 | sorting reads        | s1 |
# [####################] 100% 0:00:45 | writing/compressing  | s1 |

# %%
## use the '!' and cat command to view the stats file summarizing step 1
data_lib3.ststs
# Out:
# raw_file                               total_reads    cut_found  bar_matched
# tsuga_R1_lib3.fastq                       78509847     78503546     71116206
# tsuga_R2_lib3.fastq                       78509847     78509435          246
#
# sample_name                            total_reads
# S010                                       9296818
# S021                                       2761225
# S066                                         12758
# S075                                       6084756
# S090                                       5048505
# S122                                        718713
# S127                                       1092415
# S141                                       3265448
# S146                                      16443804
# S325                                      10655442
# S333                                       6900265
# S335                                       8836303
#
# sample_name                               true_bar       obs_bar     N_records
# S010                                         CTAGC         CTAGC       9296818
# S021                                         TTCTC         TTCTC       2761225
# S066                                        ATCACG        ATCACG         12758
# S075                                        TTAGGC        TTAGGC       6084756
# S090                                        ACAGTG        ACAGTG       5048505
# S122                                       TATTTTT       TATTTTT        718713
# S127                                       ATGAAAC       ATGAAAC       1092415
# S141                                       GAATTCA       GAATTCA       3265448
# S146                                         CTTGA         CTTGA      16443804
# S325                                         GTATT         GTATT      10655442
# S333                                         AGCAT         AGCAT       6900265
# S335                                        CGATGT        CGATGT       8836303
# no_match                                         _            _     85903242

# %%
data_lib4.run("1", ipyclient=ipyclient)
# Out:
# Parallel connection | tesla.ibest.uidaho.edu: 30 cores
# [####################] 100% 0:29:26 | sorting reads        | s1 |
# [####################] 100% 0:00:55 | writing/compressing  | s1 |

# %%
## use the '!' and cat command to view the stats file summarizing step 1
data_lib4.stats
# Out:
# raw_file                               total_reads    cut_found  bar_matched
# tsuga_R1_lib4.fastq                       97187548     97179230     88573777
# tsuga_R2_lib4.fastq                       97187548     97187165          384
#
# sample_name                            total_reads
# S004                                      19611192
# S022                                       2133177
# S078                                         36812
# S087                                      14818090
# S093                                       2393554
# S124                                       3297161
# S137                                       1106822
# S149                                       4010058
# S326                                      11132884
# S327                                      14927516
# S328                                      11482519
# S334                                       3624376
#
# sample_name                               true_bar       obs_bar     N_records
# S004                                         CTTGA         CTTGA      19611192
# S022                                         CTAGC         CTAGC       2133177
# S078                                        ATCACG        ATCACG         36812
# S087                                        TTAGGC        TTAGGC      14818090
# S093                                        ACAGTG        ACAGTG       2393554
# S124                                       TATTTTT       TATTTTT       3297161
# S137                                       ATGAAAC       ATGAAAC       1106822
# S149                                       GAATTCA       GAATTCA       4010058
# S326                                         TTCTC         TTCTC      11132884
# S327                                         GTATT         GTATT      14927516
# S328                                         AGCAT         AGCAT      11482519
# S334                                        CGATGT        CGATGT       3624376
# no_match                                         _             _     105800935

# %% [markdown]
# # Merge all four libraries

# %%
## merge the demiltiplexed libraries of tsuga; there are 4
FullTsugaData =  ip.merge("AllTsugaLibs", [data_lib1, data_lib2, data_lib3, data_lib4])

# %%
## check the parameters of the combined libraries and adjust parameters for step 2
FullTsugaData.get_params()
# Out:
#   0   assembly_name               AllTsugaLibs
#   1   project_dir                 ./
#   2   raw_fastq_path              Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
#   3   barcodes_path               Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
#   4   sorted_fastq_path           Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
#   5   assembly_method             denovo
#   6   reference_sequence
#   7   datatype                    ddrad
#   8   restriction_overhang        ('TGCAG', 'CCGG')
#   9   max_low_qual_bases          5
#   10  phred_Qscore_offset         33
#   11  mindepth_statistical        6
#   12  mindepth_majrule            6
#   13  maxdepth                    10000
#   14  clust_threshold             0.85
#   15  max_barcode_mismatch        0
#   16  filter_adapters             0
#   17  filter_min_trim_len         35
#   18  max_alleles_consens         2
#   19  max_Ns_consens              (5, 5)
#   20  max_Hs_consens              (8, 8)
#   21  min_samples_locus           4
#   22  max_SNPs_locus              (20, 20)
#   23  max_Indels_locus            (8, 8)
#   24  max_shared_Hs_locus         0.5
#   25  trim_reads                  (0, 0, 0, 0)
#   26  trim_loci                   (0, 0, 0, 0)
#   27  output_formats              ['G', 'a', 'g', 'k', 'm', 'l', 'n', 'p', 's', 'u', 't', 'v']
#   28  pop_assign_file

# %%
## changing filter adapters to 2 means reads are searched for illumina adaptors
FullTsugaData.set_params("filter_adapters", 2)

# %%
## changing filter adapters to 2 means reads are searched for illumina adaptors
FullTsugaData.set_params("filter_adapters", 2)
## for steps 3 and 6
FullTsugaData.set_params("clust_threshold", 0.8)
## for steps 4 and 5
FullTsugaData.set_params("mindepth_statistical", 10)
FullTsugaData.set_params("mindepth_majrule", 5)
FullTsugaData.set_params("maxdepth", 50000)
FullTsugaData.set_params("max_Hs_consens", 0.10)
FullTsugaData.set_params("max_Ns_consens", 0.10)

## for step 7
FullTsugaData.set_params("min_samples_locus", 10)

FullTsugaData.get_params()
# Out:
# 0   assembly_name               FullTsugaData_AS2
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 3   barcodes_path               Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 4   sorted_fastq_path           Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        10
# 12  mindepth_majrule            5
# 13  maxdepth                    50000
# 14  clust_threshold             0.8
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.1
# 20  max_Hs_consens              0.1
# 21  min_samples_locus           10
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
## run step 2
FullTsugaData.run("2", ipyclient=ipyclient)
# Out:
#   Assembly: AllTsugaLibs
#   [####################] 100%  processing reads      | 0:24:04 | s2 |

# %%
## load the json file from an assembly 
FullTsugaData = ip.load_json("FullTsugaData_AS2.json")
# Out:
# loading Assembly: FullTsugaData_AS2
# from saved path: /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly/FullTsugaData_AS2.json

# %%
## look at the number of reads after the filtering
FullTsugaData.get_params()
# Out:
# 0   assembly_name               FullTsugaData_AS2
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 3   barcodes_path               Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 4   sorted_fastq_path           Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        10
# 12  mindepth_majrule            5
# 13  maxdepth                    50000
# 14  clust_threshold             0.8
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.1
# 20  max_Hs_consens              0.1
# 21  min_samples_locus           10
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
## for step 3, don't need to change anything because keeping the clust threshold at 0.85
## for step 4, leave max alleles at 2
## for step 5, leave max Ns at 5 bc the reads are pretty short (~50 bp)
## for step 6, nothing changes

## run step 3456
FullTsugaData.run("3",force=True, ipyclient=ipyclient)
# Out:
# Parallel connection | crick.ibest.uidaho.edu: 48 cores
# [####################] 100% 0:01:26 | dereplicating        | s3 |
# [####################] 100% 0:41:05 | clustering/mapping   | s3 |
# [####################] 100% 0:00:13 | building clusters    | s3 |
# [####################] 100% 0:00:02 | chunking clusters    | s3 |
# [####################] 100% 1:01:09 | aligning clusters    | s3 |
# [####################] 100% 0:00:09 | concat clusters      | s3 |
# [####################] 100% 0:00:08 | calc cluster stats   | s3 |

# %%
FullTsugaData.branch("FullTsugaData_AS3")

# %%
FullTsugaData.stats
# Out:
#       state  reads_raw  reads_passed_filter  clusters_total  clusters_hidepth
# S004      3   19611192             19531270          415086            198388
# S006      3   10111530             10059201          375737            160219
# S010      3    9296818              9287589          239983            120982
# S011      3    3281231              3272284          199751             74638
# S014      3    5161631              5142832          218847             90937
# S016      3    4889141              4875493          263523            105710
# S021      3    2761225              2759551           79674             28493
# S022      3    2133177              2126321           90925             31671
# S024      3    2030919              2023367           90956             26213
# S066      3      12758                12728            2232               873
# S069      3       8220                 8180            1621               549
# S072      3       6183                 6134            1278               419
# S075      3    6084756              6078660          188115             84525
# S078      3      36812                36500            5956              2095
# S081      3   11101092             11069206          439826            191980
# S085      3   12231998             12176502          319282            147629
# S087      3   14818090             14736921          436607            198295
# S090      3    5048505              5046484           95760             47012
# S093      3    2393554              2387599           72510             28784
# S096      3    7325899              7305753          194318             93361
# S122      3     718713               718385           34113             13862
# S124      3    3297161              3289337           68892             27768
# S127      3    1092415              1091996           36402             17408
# S128      3     652186               650697           59982             23536
# S131      3    4107097              4097201           33786             14281
# S133      3    1153533              1149910           30733             12683
# S136      3   27629244             27594748           97167             43241
# S137      3    1106822              1103077           93365             38244
# S140      3   30741507             30679704           78573             35885
# S141      3    3265448              3263986           35690             15126
# S142      3    7227747              7215613          178567             80679
# S146      3   16443804             16435214          304354            163533
# S149      3    4010058              3999004           59127             24160
# S176      3    9736582              9700452          330203            151478
# S322      3    8845425              8814975          377891            163957
# S323      3   10526134             10476025          409884            185777
# S324      3    2840110              2835559          122887             50518
# S325      3   10655442             10649195          389803            187036
# S326      3   11132884             11095876          442704            198890
# S327      3   14927516             14871084          532335            244717
# S328      3   11482519             11444129          324361            147456
# S330      3   11896726             11848685          472908            214165
# S332      3    2820766              2814852          138907             58223
# S333      3    6900265              6895889          289617            143207
# S334      3    3624376              3615843          166946             70975
# S335      3    8836303              8832501          211705            113652
# S336      3    8068046              8039763          285237            130384
# S492      3    6198842              6180201          248548            111642

# %%
## for step 4, leave max alleles at 2
FullTsugaData.run("4",force=True, ipyclient=ipyclient)
# Out:
# Parallel connection | crick.ibest.uidaho.edu: 48 cores
# [####################] 100% 0:11:51 | inferring [H, E]     | s4 |

# %%
FullTsugaData.branch("FullTsugaData_AS4")

# %%
FullTsugaData.run("5",force=True, ipyclient=ipyclient)
# Out:
# Parallel connection | crick.ibest.uidaho.edu: 48 cores
# [####################] 100% 0:00:08 | calculating depths   | s5 |
# [####################] 100% 0:00:14 | chunking clusters    | s5 |
# [####################] 100% 0:27:00 | consens calling      | s5 |
# [####################] 100% 0:00:31 | indexing alleles     | s5 |

# %%
FullTsugaData.branch("FullTsugaData_AS5")

# %%
## load the json file from an assembly 
FullTsugaData = ip.load_json("FullTsugaData_AS5.json")
# Out:
# loading Assembly: FullTsugaData_AS5
# from saved path: /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly/FullTsugaData_AS5.json

# %%
FullTsugaData.stats
# Out:
#       state  reads_raw  reads_passed_filter  clusters_total  clusters_hidepth  \
# S004      5   19611192             19531270          415086            198388
# S006      5   10111530             10059201          375737            160219
# S010      5    9296818              9287589          239983            120982
# S011      5    3281231              3272284          199751             74638
# S014      5    5161631              5142832          218847             90937
# S016      5    4889141              4875493          263523            105710
# S021      5    2761225              2759551           79674             28493
# S022      5    2133177              2126321           90925             31671
# S024      5    2030919              2023367           90956             26213
# S066      5      12758                12728            2232               873
# S069      5       8220                 8180            1621               549
# S072      5       6183                 6134            1278               419
# S075      5    6084756              6078660          188115             84525
# S078      5      36812                36500            5956              2095
# S081      5   11101092             11069206          439826            191980
# S085      5   12231998             12176502          319282            147629
# S087      5   14818090             14736921          436607            198295
# S090      5    5048505              5046484           95760             47012
# S093      5    2393554              2387599           72510             28784
# S096      5    7325899              7305753          194318             93361
# S122      5     718713               718385           34113             13862
# S124      5    3297161              3289337           68892             27768
# S127      5    1092415              1091996           36402             17408
# S128      5     652186               650697           59982             23536
# S131      5    4107097              4097201           33786             14281
# S133      5    1153533              1149910           30733             12683
# S136      5   27629244             27594748           97167             43241
# S137      5    1106822              1103077           93365             38244
# S140      5   30741507             30679704           78573             35885
# S141      5    3265448              3263986           35690             15126
# S142      5    7227747              7215613          178567             80679
# S146      5   16443804             16435214          304354            163533
# S149      5    4010058              3999004           59127             24160
# S176      5    9736582              9700452          330203            151478
# S322      5    8845425              8814975          377891            163957
# S323      5   10526134             10476025          409884            185777
# S324      5    2840110              2835559          122887             50518
# S325      5   10655442             10649195          389803            187036
# S326      5   11132884             11095876          442704            198890
# S327      5   14927516             14871084          532335            244717
# S328      5   11482519             11444129          324361            147456
# S330      5   11896726             11848685          472908            214165
# S332      5    2820766              2814852          138907             58223
# S333      5    6900265              6895889          289617            143207
# S334      5    3624376              3615843          166946             70975
# S335      5    8836303              8832501          211705            113652
# S336      5    8068046              8039763          285237            130384
# S492      5    6198842              6180201          248548            111642
#
#       hetero_est  error_est  reads_consens
# S004    0.023662   0.001977         188257
# S006    0.027794   0.002627         150192
# S010    0.023620   0.002155         113957
# S011    0.023100   0.002356          71284
# S014    0.021263   0.001963          87028
# S016    0.025444   0.002610         100082
# S021    0.023739   0.002473          27188
# S022    0.025071   0.002574          30265
# S024    0.023691   0.001663          25078
# S066    0.008002   0.001222            862
# S069    0.006457   0.001093            543
# S072    0.003368   0.000996            418
# S075    0.021711   0.002387          80155
# S078    0.010289   0.001202           2047
# S081    0.027988   0.002966         179049
# S085    0.023256   0.002203         139451
# S087    0.027967   0.002414         185847
# S090    0.020458   0.001655          45041
# S093    0.022697   0.001900          27484
# S096    0.022546   0.002443          88748
# S122    0.017537   0.001158          13448
# S124    0.020342   0.001266          26777
# S127    0.015547   0.001207          16873
# S128    0.020328   0.001959          22661
# S131    0.011528   0.000957          14052
# S133    0.012002   0.001054          12429
# S136    0.013144   0.000856          42440
# S137    0.024111   0.002587          36329
# S140    0.015214   0.000696          35193
# S141    0.012617   0.001012          14862
# S142    0.019487   0.001863          77305
# S146    0.017734   0.001683         156691
# S149    0.019128   0.001287          23374
# S176    0.021607   0.002231         143191
# S322    0.028410   0.003017         152914
# S323    0.022624   0.002454         175788
# S324    0.026416   0.002723          47571
# S325    0.023547   0.002323         177025
# S326    0.022423   0.002285         188939
# S327    0.026091   0.002684         229894
# S328    0.027398   0.002489         137221
# S330    0.025155   0.002586         201662
# S332    0.019419   0.002176          55881
# S333    0.023372   0.002648         134945
# S334    0.022078   0.002315          67621
# S335    0.020886   0.002197         107730
# S336    0.023661   0.002220         123166
# S492    0.022342   0.002348         106347

# %%
FullTsugaData.run("6",force=True, ipyclient=ipyclient)
# Out:
# Parallel connection | crick.ibest.uidaho.edu: 48 cores
# [####################] 100% 0:00:39 | concatenating inputs | s6 |
# [####################] 100% 0:55:18 | clustering tier 1    | s6 |
# [####################] 100% 0:00:05 | concatenating inputs | s6 |
# [####################] 100% 0:23:36 | clustering across    | s6 |
# [####################] 100% 0:00:23 | building clusters    | s6 |
# [####################] 100% 0:02:25 | aligning clusters    | s6 |

# %%
FullTsugaData.branch("FullTsugaData_AS6")

# %%
FullTsugaData.stats
# Out:
#       state  reads_raw  reads_passed_filter  clusters_total  clusters_hidepth  \
# S004      6   19611192             19531270          415086            198388
# S006      6   10111530             10059201          375737            160219
# S010      6    9296818              9287589          239983            120982
# S011      6    3281231              3272284          199751             74638
# S014      6    5161631              5142832          218847             90937
# S016      6    4889141              4875493          263523            105710
# S021      6    2761225              2759551           79674             28493
# S022      6    2133177              2126321           90925             31671
# S024      6    2030919              2023367           90956             26213
# S066      6      12758                12728            2232               873
# S069      6       8220                 8180            1621               549
# S072      6       6183                 6134            1278               419
# S075      6    6084756              6078660          188115             84525
# S078      6      36812                36500            5956              2095
# S081      6   11101092             11069206          439826            191980
# S085      6   12231998             12176502          319282            147629
# S087      6   14818090             14736921          436607            198295
# S090      6    5048505              5046484           95760             47012
# S093      6    2393554              2387599           72510             28784
# S096      6    7325899              7305753          194318             93361
# S122      6     718713               718385           34113             13862
# S124      6    3297161              3289337           68892             27768
# S127      6    1092415              1091996           36402             17408
# S128      6     652186               650697           59982             23536
# S131      6    4107097              4097201           33786             14281
# S133      6    1153533              1149910           30733             12683
# S136      6   27629244             27594748           97167             43241
# S137      6    1106822              1103077           93365             38244
# S140      6   30741507             30679704           78573             35885
# S141      6    3265448              3263986           35690             15126
# S142      6    7227747              7215613          178567             80679
# S146      6   16443804             16435214          304354            163533
# S149      6    4010058              3999004           59127             24160
# S176      6    9736582              9700452          330203            151478
# S322      6    8845425              8814975          377891            163957
# S323      6   10526134             10476025          409884            185777
# S324      6    2840110              2835559          122887             50518
# S325      6   10655442             10649195          389803            187036
# S326      6   11132884             11095876          442704            198890
# S327      6   14927516             14871084          532335            244717
# S328      6   11482519             11444129          324361            147456
# S330      6   11896726             11848685          472908            214165
# S332      6    2820766              2814852          138907             58223
# S333      6    6900265              6895889          289617            143207
# S334      6    3624376              3615843          166946             70975
# S335      6    8836303              8832501          211705            113652
# S336      6    8068046              8039763          285237            130384
# S492      6    6198842              6180201          248548            111642
#
#       hetero_est  error_est  reads_consens
# S004    0.023662   0.001977         188257
# S006    0.027794   0.002627         150192
# S010    0.023620   0.002155         113957
# S011    0.023100   0.002356          71284
# S014    0.021263   0.001963          87028
# S016    0.025444   0.002610         100082
# S021    0.023739   0.002473          27188
# S022    0.025071   0.002574          30265
# S024    0.023691   0.001663          25078
# S066    0.008002   0.001222            862
# S069    0.006457   0.001093            543
# S072    0.003368   0.000996            418
# S075    0.021711   0.002387          80155
# S078    0.010289   0.001202           2047
# S081    0.027988   0.002966         179049
# S085    0.023256   0.002203         139451
# S087    0.027967   0.002414         185847
# S090    0.020458   0.001655          45041
# S093    0.022697   0.001900          27484
# S096    0.022546   0.002443          88748
# S122    0.017537   0.001158          13448
# S124    0.020342   0.001266          26777
# S127    0.015547   0.001207          16873
# S128    0.020328   0.001959          22661
# S131    0.011528   0.000957          14052
# S133    0.012002   0.001054          12429
# S136    0.013144   0.000856          42440
# S137    0.024111   0.002587          36329
# S140    0.015214   0.000696          35193
# S141    0.012617   0.001012          14862
# S142    0.019487   0.001863          77305
# S146    0.017734   0.001683         156691
# S149    0.019128   0.001287          23374
# S176    0.021607   0.002231         143191
# S322    0.028410   0.003017         152914
# S323    0.022624   0.002454         175788
# S324    0.026416   0.002723          47571
# S325    0.023547   0.002323         177025
# S326    0.022423   0.002285         188939
# S327    0.026091   0.002684         229894
# S328    0.027398   0.002489         137221
# S330    0.025155   0.002586         201662
# S332    0.019419   0.002176          55881
# S333    0.023372   0.002648         134945
# S334    0.022078   0.002315          67621
# S335    0.020886   0.002197         107730
# S336    0.023661   0.002220         123166
# S492    0.022342   0.002348         106347

# %%
FullTsugaData.get_params()
# Out:
# 0   assembly_name               AllTsugaLibs
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 3   barcodes_path               Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 4   sorted_fastq_path           Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
## look at the number of reads after the filtering
FullTsugaData.stats
# Out:
#       state  reads_raw  reads_passed_filter  clusters_total  clusters_hidepth  \
# S004      6   19611192             19531270          415086            198388
# S006      6   10111530             10059201          375737            160219
# S010      6    9296818              9287589          239983            120982
# S011      6    3281231              3272284          199751             74638
# S014      6    5161631              5142832          218847             90937
# S016      6    4889141              4875493          263523            105710
# S021      6    2761225              2759551           79674             28493
# S022      6    2133177              2126321           90925             31671
# S024      6    2030919              2023367           90956             26213
# S066      6      12758                12728            2232               873
# S069      6       8220                 8180            1621               549
# S072      6       6183                 6134            1278               419
# S075      6    6084756              6078660          188115             84525
# S078      6      36812                36500            5956              2095
# S081      6   11101092             11069206          439826            191980
# S085      6   12231998             12176502          319282            147629
# S087      6   14818090             14736921          436607            198295
# S090      6    5048505              5046484           95760             47012
# S093      6    2393554              2387599           72510             28784
# S096      6    7325899              7305753          194318             93361
# S122      6     718713               718385           34113             13862
# S124      6    3297161              3289337           68892             27768
# S127      6    1092415              1091996           36402             17408
# S128      6     652186               650697           59982             23536
# S131      6    4107097              4097201           33786             14281
# S133      6    1153533              1149910           30733             12683
# S136      6   27629244             27594748           97167             43241
# S137      6    1106822              1103077           93365             38244
# S140      6   30741507             30679704           78573             35885
# S141      6    3265448              3263986           35690             15126
# S142      6    7227747              7215613          178567             80679
# S146      6   16443804             16435214          304354            163533
# S149      6    4010058              3999004           59127             24160
# S176      6    9736582              9700452          330203            151478
# S322      6    8845425              8814975          377891            163957
# S323      6   10526134             10476025          409884            185777
# S324      6    2840110              2835559          122887             50518
# S325      6   10655442             10649195          389803            187036
# S326      6   11132884             11095876          442704            198890
# S327      6   14927516             14871084          532335            244717
# S328      6   11482519             11444129          324361            147456
# S330      6   11896726             11848685          472908            214165
# S332      6    2820766              2814852          138907             58223
# S333      6    6900265              6895889          289617            143207
# S334      6    3624376              3615843          166946             70975
# S335      6    8836303              8832501          211705            113652
# S336      6    8068046              8039763          285237            130384
# S492      6    6198842              6180201          248548            111642
#
#       hetero_est  error_est  reads_consens
# S004    0.023662   0.001977         188257
# S006    0.027794   0.002627         150192
# S010    0.023620   0.002155         113957
# S011    0.023100   0.002356          71284
# S014    0.021263   0.001963          87028
# S016    0.025444   0.002610         100082
# S021    0.023739   0.002473          27188
# S022    0.025071   0.002574          30265
# S024    0.023691   0.001663          25078
# S066    0.008002   0.001222            862
# S069    0.006457   0.001093            543
# S072    0.003368   0.000996            418
# S075    0.021711   0.002387          80155
# S078    0.010289   0.001202           2047
# S081    0.027988   0.002966         179049
# S085    0.023256   0.002203         139451
# S087    0.027967   0.002414         185847
# S090    0.020458   0.001655          45041
# S093    0.022697   0.001900          27484
# S096    0.022546   0.002443          88748
# S122    0.017537   0.001158          13448
# S124    0.020342   0.001266          26777
# S127    0.015547   0.001207          16873
# S128    0.020328   0.001959          22661
# S131    0.011528   0.000957          14052
# S133    0.012002   0.001054          12429
# S136    0.013144   0.000856          42440
# S137    0.024111   0.002587          36329
# S140    0.015214   0.000696          35193
# S141    0.012617   0.001012          14862
# S142    0.019487   0.001863          77305
# S146    0.017734   0.001683         156691
# S149    0.019128   0.001287          23374
# S176    0.021607   0.002231         143191
# S322    0.028410   0.003017         152914
# S323    0.022624   0.002454         175788
# S324    0.026416   0.002723          47571
# S325    0.023547   0.002323         177025
# S326    0.022423   0.002285         188939
# S327    0.026091   0.002684         229894
# S328    0.027398   0.002489         137221
# S330    0.025155   0.002586         201662
# S332    0.019419   0.002176          55881
# S333    0.023372   0.002648         134945
# S334    0.022078   0.002315          67621
# S335    0.020886   0.002197         107730
# S336    0.023661   0.002220         123166
# S492    0.022342   0.002348         106347

# %%
FullTsugaData.branch("FullTsugaData_AS6")

# %%
FullTsugaData.set_params("min_samples_locus", 25)

# %%
FullTsugaData.run("7",force=True, ipyclient=ipyclient)
# Out:
# Parallel connection | crick.ibest.uidaho.edu: 48 cores
# [####################] 100% 0:00:14 | applying filters     | s7 |
# [####################] 100% 0:00:04 | building arrays      | s7 |
# [####################] 100% 0:00:02 | writing conversions  | s7 |
# [####################] 100% 0:00:04 | indexing vcf depths  | s7 |
# [####################] 100% 0:00:09 | writing vcf output   | s7 |

# %%
LimitSamples = ["S004", "S006", "S010", "S011", "S014", "S016", "S021", "S022", "S024", "S075", "S081","S085", 
               "S087", "S090", "S093", "S096", "S137", "S142", "S146", "S149", "S176", "S323",
               "S324", "S325", "S326", "S327", "S328", "S330", "S332", "S333", "S334", "S335", "S336", "S492"]

TsugaSampleLimit = FullTsugaData.branch("TsugaSampleLimit", subsamples=LimitSamples)

# %%
TsugaSampleLimit.set_params("filter_min_trim_len", 125)

# %%
TsugaSampleLimit.get_params()
# Out:
# 0   assembly_name               TsugaSampleLimit
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 3   barcodes_path               Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 4   sorted_fastq_path           Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        10
# 12  mindepth_majrule            5
# 13  maxdepth                    50000
# 14  clust_threshold             0.8
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         125
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.1
# 20  max_Hs_consens              0.1
# 21  min_samples_locus           25
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
TsugaSampleLimit.run("7", force=True, ipyclient=ipyclient)
# Out:
# Parallel connection | crick.ibest.uidaho.edu: 48 cores
# [####################] 100% 0:00:07 | applying filters     | s7 |
# [####################] 100% 0:00:02 | building arrays      | s7 |
# [####################] 100% 0:00:02 | writing conversions  | s7 |
# [####################] 100% 0:00:03 | indexing vcf depths  | s7 |
# [####################] 100% 0:00:03 | writing vcf output   | s7 |

# %%
FullTsugaData.get_params()
# Out:
# 0   assembly_name               FullTsugaData_AS5
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 3   barcodes_path               Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 4   sorted_fastq_path           Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        10
# 12  mindepth_majrule            5
# 13  maxdepth                    50000
# 14  clust_threshold             0.8
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.1
# 20  max_Hs_consens              0.1
# 21  min_samples_locus           25
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
## change max Ns to like 20? and max SNPs for step 5
FullTsugaData.set_params("max_Ns_consens", (20, 20))
FullTsugaData.set_params("max_SNPs_locus", (50, 50))

# %%
FullTsugaData.stats
# Out:
#       state  reads_raw  reads_passed_filter  clusters_total  clusters_hidepth  \
# S004      6   19611192             19531270          435474            187146
# S006      6   10111530             10059201          395842            149909
# S010      6    9296818              9287589          253944            115637
# S011      6    3281231              3272284          207268             66995
# S014      6    5161631              5142832          226798             83296
# S016      6    4889141              4875493          274663             96804
# S021      6    2761225              2759551           82559             25694
# S022      6    2133177              2126321           94376             28409
# S024      6    2030919              2023367           94266             23452
# S066      6      12758                12728            2248               740
# S069      6       8220                 8180            1631               480
# S072      6       6183                 6134            1279               358
# S075      6    6084756              6078660          197118             79310
# S078      6      36812                36500            6020              1844
# S081      6   11101092             11069206          465180            180993
# S085      6   12231998             12176502          334762            139885
# S087      6   14818090             14736921          462267            187822
# S090      6    5048505              5046484           98874             43465
# S093      6    2393554              2387599           74836             26284
# S096      6    7325899              7305753          202139             87723
# S122      6     718713               718385           34816             11936
# S124      6    3297161              3289337           70809             24901
# S127      6    1092415              1091996           37174             15675
# S128      6     652186               650697           61517             20851
# S131      6    4107097              4097201           34525             12822
# S133      6    1153533              1149910           31240             11351
# S136      6   27629244             27594748          102022             39484
# S137      6    1106822              1103077           96781             34844
# S140      6   30741507             30679704           81849             32970
# S141      6    3265448              3263986           36335             13397
# S142      6    7227747              7215613          185004             75398
# S146      6   16443804             16435214          317658            156038
# S149      6    4010058              3999004           60799             21622
# S176      6    9736582              9700452          347180            143112
# S322      6    8845425              8814975          400240            153660
# S323      6   10526134             10476025          429339            174446
# S324      6    2840110              2835559          128686             46574
# S325      6   10655442             10649195          409793            173914
# S326      6   11132884             11095876          462789            185551
# S327      6   14927516             14871084          562346            231810
# S328      6   11482519             11444129          345209            141358
# S330      6   11896726             11848685          497274            201396
# S332      6    2820766              2814852          143550             52861
# S333      6    6900265              6895889          305126            134659
# S334      6    3624376              3615843          173475             65124
# S335      6    8836303              8832501          222444            109117
# S336      6    8068046              8039763          298902            122531
# S492      6    6198842              6180201          258503            103496
#
#       hetero_est  error_est  reads_consens
# S004    0.019144   0.001489         165790
# S006    0.019692   0.002072         130429
# S010    0.016037   0.001764         103182
# S011    0.015029   0.001896          60703
# S014    0.015165   0.001607          75642
# S016    0.016811   0.002175          85857
# S021    0.016692   0.002304          22748
# S022    0.017512   0.002277          25002
# S024    0.017380   0.001440          20813
# S066    0.004126   0.001158            714
# S069    0.004825   0.001040            462
# S072    0.001886   0.000928            351
# S075    0.014814   0.002072          71455
# S078    0.004921   0.001091           1773
# S081    0.019877   0.002277         157214
# S085    0.016612   0.001886         124269
# S087    0.020277   0.002070         162101
# S090    0.014403   0.001498          39647
# S093    0.014060   0.001445          23951
# S096    0.015660   0.001964          79099
# S122    0.011665   0.001135          11124
# S124    0.012559   0.001183          23077
# S127    0.011126   0.001140          14702
# S128    0.013392   0.001695          19196
# S131    0.009229   0.000940          12074
# S133    0.008252   0.001015          10825
# S136    0.010243   0.000833          36690
# S137    0.015433   0.002030          31655
# S140    0.011669   0.000719          30676
# S141    0.010084   0.001032          12584
# S142    0.014171   0.001576          68657
# S146    0.012460   0.001461         143468
# S149    0.013643   0.001221          19823
# S176    0.015139   0.001802         128760
# S322    0.018239   0.002281         135090
# S323    0.015836   0.001852         155278
# S324    0.017544   0.002156          41471
# S325    0.014639   0.001823         157744
# S326    0.015593   0.002007         166102
# S327    0.018371   0.002067         203834
# S328    0.018947   0.001947         123528
# S330    0.017263   0.002032         178989
# S332    0.013005   0.001802          48408
# S333    0.015081   0.002131         121967
# S334    0.013735   0.001877          59430
# S335    0.014048   0.001773          99536
# S336    0.015594   0.001754         110532
# S492    0.015568   0.001737          93673

# %%
## run step 6, nothing changes here
FullTsugaData.run("6",force=True, ipyclient=ipyclient)
# Out:
#   Assembly: AllTsugaLibs
#   [####################] 100%  concat/shuffle input  | 0:00:48 | s6 |
#   [####################] 100%  clustering across     | 0:39:52 | s6 |
#   [####################] 100%  building clusters     | 0:00:34 | s6 |
#   [####################] 100%  aligning clusters     | 0:03:25 | s6 |
#   [####################] 100%  database indels       | 0:02:14 | s6 |
#   [####################] 100%  indexing clusters     | 0:02:13 | s6 |
#   [####################] 100%  building database     | 0:38:16 | s6 |

# %%
## make branch for new output files with min sample locus at 20
MinSamp20 = FullTsugaData.branch("TsugaMinSamp20")

# %%
MinSamp20.get_params()
# Out:
# 0   assembly_name               TsugaMinSamp20
# 1   project_dir                 /mnt/lfs2/ruff6699/Tsugaheterophylla_AllDataAnalysis/TsugaIpyradAssembly
# 2   raw_fastq_path              Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 3   barcodes_path               Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 4   sorted_fastq_path           Merged: tsuga_lib1, tsuga_lib2, tsuga_lib3, tsuga_lib4
# 5   assembly_method             denovo
# 6   reference_sequence
# 7   datatype                    ddrad
# 8   restriction_overhang        ('TGCAG', 'CCGG')
# 9   max_low_qual_bases          5
# 10  phred_Qscore_offset         33
# 11  mindepth_statistical        6
# 12  mindepth_majrule            6
# 13  maxdepth                    10000
# 14  clust_threshold             0.85
# 15  max_barcode_mismatch        0
# 16  filter_adapters             2
# 17  filter_min_trim_len         35
# 18  max_alleles_consens         2
# 19  max_Ns_consens              0.05
# 20  max_Hs_consens              0.05
# 21  min_samples_locus           4
# 22  max_SNPs_locus              0.2
# 23  max_Indels_locus            8
# 24  max_shared_Hs_locus         0.5
# 25  trim_reads                  (0, 0, 0, 0)
# 26  trim_loci                   (0, 0, 0, 0)
# 27  output_formats              ['l', 'p', 's', 'n', 'k', 'a', 'g', 'G', 'u', 'v', 't', 'm']
# 28  pop_assign_file
# 29  reference_as_filter

# %%
## run step 7, nothing changes here
FullTsugaData.run("7", force=True, ipyclient=ipyclient)
# Out:
# Parallel connection | tesla.ibest.uidaho.edu: 48 cores
#
# Encountered an Error.
# Message: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Traceback (most recent call last):
#   File "/mnt/ceph/ruff6699/miniconda3/envs/ipyrad/lib/python3.7/site-packages/ipyrad/core/Parallel.py", line 313, in wrap_run
#     self.tool._run(ipyclient=self.ipyclient, **self.rkwargs)
#   File "/mnt/ceph/ruff6699/miniconda3/envs/ipyrad/lib/python3.7/site-packages/ipyrad/core/assembly.py", line 686, in _run
#     stepdict[step](self, force, ipyclient).run()
#   File "/mnt/ceph/ruff6699/miniconda3/envs/ipyrad/lib/python3.7/site-packages/ipyrad/assemble/write_outputs.py", line 47, in __init__
#     self.samples = self.get_subsamples()
#   File "/mnt/ceph/ruff6699/miniconda3/envs/ipyrad/lib/python3.7/site-packages/ipyrad/assemble/write_outputs.py", line 108, in get_subsamples
#     dbsamples = inloci.readline()[1:].strip().split(",@")
#   File "/mnt/ceph/ruff6699/miniconda3/envs/ipyrad/lib/python3.7/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
