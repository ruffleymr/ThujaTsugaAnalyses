# %%
import pandas as pd
import numpy as np

# %%
infile="jAFS_d3_ParamEst.obs"
obs_sfs = pd.read_table(infile)
obs_sfs
# Out:
#    Unnamed: 0         d0_0         d0_1        d0_2        d0_3        d0_4  \
# 0        d1_0  3911.403782  1963.986437  816.709673  290.621517  198.815227
# 1        d1_1   138.488247    96.890736   61.189204   38.318043   27.654157
# 2        d1_2    42.733594    30.959762   26.179277   22.104910   20.055415
# 3        d1_3    24.769778    18.301261   12.634149   11.711277    0.000000
# 4        d1_4     0.000000     0.000000    0.000000  376.730002   81.102998
# 5        d1_5   267.557115    65.736717   66.278621   58.962031   64.774210
# 6        d1_6    47.258619    50.755050   46.091069   45.475477   41.053068
# 7        d1_7    43.198720    41.491416    0.000000    0.000000    0.000000
# 8        d1_8     0.000000     0.000000    0.000000    0.000000    0.000000
# 9        d1_9     0.000000     0.000000    0.000000   55.134537   24.279127
# 10      d1_10    46.157655    19.126968   19.067417   15.811030    0.000000
# ...

# %%
jSFS = obs_sfs.drop(obs_sfs.columns[[0]], axis=1)

# %%
jSFS
# Out:
#            d0_0         d0_1        d0_2        d0_3        d0_4        d0_5  \
# 0   3911.403782  1963.986437  816.709673  290.621517  198.815227  110.193343
# 1    138.488247    96.890736   61.189204   38.318043   27.654157   21.893341
# 2     42.733594    30.959762   26.179277   22.104910   20.055415   14.157451
# 3     24.769778    18.301261   12.634149   11.711277    0.000000    0.000000
# 4      0.000000     0.000000    0.000000  376.730002   81.102998   82.662571
# 5    267.557115    65.736717   66.278621   58.962031   64.774210   48.979880
# 6     47.258619    50.755050   46.091069   45.475477   41.053068   38.628511
# 7     43.198720    41.491416    0.000000    0.000000    0.000000    0.000000
# 8      0.000000     0.000000    0.000000    0.000000    0.000000    0.000000
# 9      0.000000     0.000000    0.000000   55.134537   24.279127   26.245930
# 10    46.157655    19.126968   19.067417   15.811030    0.000000    0.000000
# ...

# %%
ALLsnps = np.sum(np.sum(jSFS, axis=1))
ALLsnps
# Out:
# 20724.000000000073

# %%
## input file for parameter estimates for ThujajAFS_d3_ForParamEst.obs
infile ="jAFS_d3_ParamEst.obs"

# %%
jSFSfile = open(infile, "r")
##get ride of first two lines
allLines = jSFSfile.readlines()
allLines = allLines[2:]

# %%
allLinesallLines
# Out:
# ['d1_0\t3911.403782193901 1963.986436704424 816.7096727944424 290.6215166534836 198.8152269028916 110.1933427181623 100.5723525371179 54.14223161374683 44.62404728712639 34.37045728947071 24.88499041132458 19.93495369220623 20.39406975644497 14.86108939870568 52.29597605438708 3075.166872282226 400.0687342802146 257.6282728152913\n',
#  'd1_1\t138.4882466945223 96.89073585282986 61.18920354668642 38.31804344561868 27.65415685770868 21.89334148554998 16.87924516999421 14.86652576112308 10.94921250027563 10.38094099412623 10.86553087550531 32.98255420898501 1647.359720083964 267.4438033825524 208.1264657649273 121.0118141020115 90.71080802116182 64.08748678977253\n',
#  'd1_2\t42.73359441610419 30.95976216403006 26.17927749924907 22.10490981115597 20.05541458969739 14.15745105469575 14.06730479531977 11.07164875165162 0 802.244592775035 157.2837617868084 139.6799857362773 90.93765966573156 73.50937694262203 54.38396468843958 40.66537428575099 30.0343857436857 26.29743019709975\n',
# ...

# %%
sumfile="jAFS_edited_forParam4plot.obs"
outFile = open(sumfile, "a")
for line in allLines:
    rows = line.split("\t")[1].strip()
    print(rows)
    sites = rows.split(" ")
    for singleSiteFreq in sites:
        print(singleSiteFreq+"\t")
        outFile.write(singleSiteFreq+"\t")

## add return for each SFS flattened
summaryOutputfile.write("\n")
# Out:
# 3911.403782193901 1963.986436704424 816.7096727944424 290.6215166534836 198.8152269028916 110.1933427181623 100.5723525371179 54.14223161374683 44.62404728712639 34.37045728947071 24.88499041132458 19.93495369220623 20.39406975644497 14.86108939870568 52.29597605438708 3075.166872282226 400.0687342802146 257.6282728152913
# 3911.403782193901
# 1963.986436704424
# 816.7096727944424
# 290.6215166534836
# 198.8152269028916
# 110.1933427181623
# 100.5723525371179
# 54.14223161374683
# 44.62404728712639
# 34.37045728947071
# 24.88499041132458
# 19.93495369220623
# 20.39406975644497
# 14.86108939870568
# 52.29597605438708
# 3075.166872282226
# 400.0687342802146
# 257.6282728152913
# ...

# %%
infile="jAFS_edited_forParam4plot.obs"
obs_sfs = pd.read_table(infile)
#obs_sfs

# %%
infile="jAFS_d3_ParamEst.obs"
obs_sfs = pd.read_table(infile)
obs_sfs
# Out:
#    Unnamed: 0         d0_0         d0_1        d0_2        d0_3        d0_4  \
# 0        d1_0  3911.403782  1963.986437  816.709673  290.621517  198.815227
# 1        d1_1   138.488247    96.890736   61.189204   38.318043   27.654157
# 2        d1_2    42.733594    30.959762   26.179277   22.104910   20.055415
# 3        d1_3    24.769778    18.301261   12.634149   11.711277    0.000000
# 4        d1_4     0.000000     0.000000    0.000000  376.730002   81.102998
# 5        d1_5   267.557115    65.736717   66.278621   58.962031   64.774210
# 6        d1_6    47.258619    50.755050   46.091069   45.475477   41.053068
# 7        d1_7    43.198720    41.491416    0.000000    0.000000    0.000000
# 8        d1_8     0.000000     0.000000    0.000000    0.000000    0.000000
# 9        d1_9     0.000000     0.000000    0.000000   55.134537   24.279127
# 10      d1_10    46.157655    19.126968   19.067417   15.811030    0.000000
# ...
